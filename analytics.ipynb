# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("fitness_log.csv")

# %%
data
# Out:
#      generation  best_fitness  avg_fitness       stdev
# 0             0          -835 -1014.993333   23.777439
# 1             1          -912 -1011.700000   25.364214
# 2             2          -930 -1017.220000   28.899105
# 3             3          -903 -1009.580000   24.336877
# 4             4          -908 -1009.033333   22.213034
# ..          ...           ...          ...         ...
# 195         195          2311  -618.630872  623.419681
# 196         196          1820  -566.466667  636.731484
# 197         197          1495  -547.384106  637.900477
# 198         198          1665  -503.986577  665.888769
# 199         199          2630  -537.800000  628.040211
#
# [200 rows x 4 columns]

# %%
fig, ax = plt.subplots(figsize=(20,10))

ax.plot(data['avg_fitness'], label = 'avg fitness')
ax.set_ylabel('avg fitness')

ax2 = ax.twinx()
ax2.plot(data['best_fitness'], color='orange', label = 'best fitness')
ax2.set_ylabel('best fitness')

fig.legend()
plt.title("fitness over generations")
# Out:
# Text(0.5, 1.0, 'fitness over generations')
